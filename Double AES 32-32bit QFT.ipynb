# %%
import time
import sys
from projectq import MainEngine
from projectq.ops import H, Measure, All, CNOT
from projectq.backends import Simulator
from projectq.cengines import TagRemover

# Helper function for Quantum Fourier Transform
def apply_qft(eng, qubits):
    n = len(qubits)
    for i in range(n):
        H | qubits[i]
        for j in range(i + 1, n):
            CNOT | (qubits[j], qubits[i])

# Helper function for Inverse Quantum Fourier Transform (QFT†)
def apply_inverse_qft(eng, qubits):
    n = len(qubits)
    for i in reversed(range(n)):
        for j in reversed(range(i + 1, n)):
            CNOT | (qubits[j], qubits[i])
        H | qubits[i]

# Double AES with QFT for two 16-bit keys
def Double_AES_QFT(eng, resource_check):
    # Step 1: Allocate registers for 16-bit plaintext and two 16-bit keys
    x = eng.allocate_qureg(16)   # 16-bit plaintext
    k1 = eng.allocate_qureg(16)  # First 16-bit key
    k2 = eng.allocate_qureg(16)  # Second 16-bit key

    # Step 2: Apply QFT to plaintext and keys
    print("Applying QFT to plaintext and keys...")
    apply_qft(eng, x)
    apply_qft(eng, k1)
    apply_qft(eng, k2)
    eng.flush()

    # Step 3: First AES-16 Layer
    print("Running First AES Layer (AES-16)")
    AES_16(eng, resource_check, x, k1)

    # Step 4: Apply inverse QFT to plaintext and keys
    print("Applying Inverse QFT to ciphertext and keys...")
    apply_inverse_qft(eng, x)
    apply_inverse_qft(eng, k1)
    apply_inverse_qft(eng, k2)
    eng.flush()

    # Step 5: Second AES-16 Layer with the second key
    print("Running Second AES Layer (AES-16)")
    AES_16(eng, resource_check, x, k2)

    # Step 6: Final inverse QFT on the ciphertext
    print("Applying final Inverse QFT to output...")
    apply_inverse_qft(eng, x)
    eng.flush()

    # Output final state
    print("Final Ciphertext:")
    print_state(eng, x, 4)

    return x

# AES-16 function with a 16-bit key
def AES_16(eng, resource_check, x, k):
    # Initial XOR with round constants for state and key
    if resource_check != 1:
        Round_constant_XOR(eng, x, 0x1234, 16)
        Round_constant_XOR(eng, k, 0x1234, 16)

    # Encryption rounds (2 rounds for AES-16)
    for i in range(2):
        Keyshedule_16(eng, k, i, resource_check)
        SBox_bp12_all(eng, x, resource_check)
        x = Maxi_mc(eng, x) if i != 1 else x
        AddRoundkey(eng, x, k)

    return x

# Helper functions
def Keyshedule_16(eng, k, round, resource_check):
    pass

def SBox_bp12_all(eng, x, resource_check):
    pass

def Maxi_mc(eng, x):
    return x

def AddRoundkey(eng, x, k):
    CNOT16(eng, k, x)

def Round_constant_XOR(eng, x, constant, bits):
    for i in range(bits):
        if (constant >> i) & 1:
            X | x[i]

def CNOT16(eng, a, b):
    for i in range(16):
        CNOT | (a[i], b[i])

def print_state(eng, qubits, n):
    eng.flush()
    state = []
    for i in range(n):
        state.append(int(qubits[i]))

    binary_str = ''.join(str(bit) for bit in state)
    hex_str = hex(int(binary_str, 2))[2:].zfill((n + 3) // 4)
    print(f'Hex: {hex_str.upper()}')
    print(f'Binary: {binary_str}')
    sys.stdout.flush()

# Main function to run Double AES with QFT
def main():
    start_time = time.time()

    sim = Simulator()
    eng = MainEngine(backend=sim, engine_list=[TagRemover()])

    Double_AES_QFT(eng, 0)

    end_time = time.time()
    execution_time = end_time - start_time
    print(f'\nExecution Time: {execution_time:.4f} seconds')
    sys.stdout.flush()

if __name__ == '__main__':
    main()
# Out:
# (Note: This is the (slow) Python simulator.)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_main.py:301, in MainEngine.send(self, command_list)
#     300 try:
# --> 301     self.next_engine.receive(command_list)
#     302 except Exception as err:  # pylint: disable=broad-except
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_tagremover.py:65, in TagRemover.receive(self, command_list)
#      64     cmd.tags = [t for t in cmd.tags if not isinstance(t, tag)]
# ---> 65 self.send([cmd])
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_basics.py:186, in BasicEngine.send(self, command_list)
#     185 """Forward the list of commands to the next engine in the pipeline."""
# --> 186 self.next_engine.receive(command_list)
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\backends\_sim\_simulator.py:434, in Simulator.receive(self, command_list)
#     433 if not cmd.gate == FlushGate():
# --> 434     self._handle(cmd)
#     435 else:
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\backends\_sim\_simulator.py:357, in Simulator._handle(self, cmd)
#     356     qubit_id = cmd.qubits[0][0].id
# --> 357     self._simulator.allocate_qubit(qubit_id)
#     358 elif cmd.gate == Deallocate:
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\backends\_sim\_pysim.py:114, in Simulator.allocate_qubit(self, qubit_id)
#     113 self._num_qubits += 1
# --> 114 self._state.resize(1 << self._num_qubits, refcheck=_USE_REFCHECK)
#
# MemoryError: cannot allocate memory for array
#
# The above exception was the direct cause of the following exception:
#
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 129
#     126     sys.stdout.flush()
#     128 if __name__ == '__main__':
# --> 129     main()
#
# Cell In[1], line 121, in main()
#     118 sim = Simulator()
#     119 eng = MainEngine(backend=sim, engine_list=[TagRemover()])
# --> 121 Double_AES_QFT(eng, 0)
#     123 end_time = time.time()
#     124 execution_time = end_time - start_time
#
# Cell In[1], line 28, in Double_AES_QFT(eng, resource_check)
#      25 def Double_AES_QFT(eng, resource_check):
#      26     # Step 1: Allocate registers for 16-bit plaintext and two 16-bit keys
#      27     x = eng.allocate_qureg(16)   # 16-bit plaintext
# ---> 28     k1 = eng.allocate_qureg(16)  # First 16-bit key
#      29     k2 = eng.allocate_qureg(16)  # Second 16-bit key
#      31     # Step 2: Apply QFT to plaintext and keys
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_basics.py:128, in BasicEngine.allocate_qureg(self, n_qubits)
#     119 def allocate_qureg(self, n_qubits):
#     120     """
#     121     Allocate n qubits and return them as a quantum register, which is a list of qubit objects.
#     122
#    (...)
#     126         Qureg of length n, a list of n newly allocated qubits.
#     127     """
# --> 128     return Qureg([self.allocate_qubit()[0] for _ in range(n_qubits)])
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_basics.py:128, in <listcomp>(.0)
#     119 def allocate_qureg(self, n_qubits):
#     120     """
#     121     Allocate n qubits and return them as a quantum register, which is a list of qubit objects.
#     122
#    (...)
#     126         Qureg of length n, a list of n newly allocated qubits.
#     127     """
# --> 128     return Qureg([self.allocate_qubit()[0] for _ in range(n_qubits)])
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_basics.py:116, in BasicEngine.allocate_qubit(self, dirty)
#     114         self.main_engine.dirty_qubits.add(qb[0].id)
#     115 self.main_engine.active_qubits.add(qb[0])
# --> 116 self.send([cmd])
#     117 return qb
#
# File ~\Documents\KULIAH S2\THESIS\Penelitian Bab 4\myenv\Lib\site-packages\projectq\cengines\_main.py:312, in MainEngine.send(self, command_list)
#     308 compact_exception = exc_type(
#     309     str(exc_value) + '\n raised in:\n' + repr(last_line[-3]) + "\n" + repr(last_line[-2])
#     310 )
#     311 compact_exception.__cause__ = None
# --> 312 raise compact_exception from err
#
# MemoryError: cannot allocate memory for array
#  raised in:
# '  File "C:\\Users\\jimmy\\Documents\\KULIAH S2\\THESIS\\Penelitian Bab 4\\myenv\\Lib\\site-packages\\projectq\\backends\\_sim\\_pysim.py", line 114, in allocate_qubit'
# '    self._state.resize(1 << self._num_qubits, refcheck=_USE_REFCHECK)'
