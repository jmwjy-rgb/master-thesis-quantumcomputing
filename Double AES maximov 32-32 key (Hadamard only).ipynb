# %%
import time
import sys
from projectq import MainEngine
from projectq.ops import H, Measure, All
from projectq.backends import Simulator
from projectq.cengines import TagRemover

# AES-like function with Hadamard gates applied
def AES_Hadamard(eng):
    # Step 1: Allocate quantum registers (64 qubits for each block and key)
    x0 = eng.allocate_qureg(8)  # 64 qubits for the plaintext block
    k = eng.allocate_qureg(8)   # 64 qubits for the key

    # Step 2: Apply Hadamard gates to all 64 qubits in x0 and k
    print('--- Applying Hadamard Gates to All 64 Qubits ---')
    sys.stdout.flush()
    All(H) | x0
    All(H) | k
    eng.flush()

    # Step 3: Measure the qubits after applying Hadamard gates
    print('--- Measuring the qubits after first Hadamard gates ---')
    All(Measure) | x0
    All(Measure) | k
    eng.flush()

    # Step 4: Print the initial key and plaintext after measurement
    print('Initial key (after Hadamard and measurement):')
    sys.stdout.flush()
    print_state(eng, k)

    print('Initial plaintext:')
    sys.stdout.flush()
    print_state(eng, x0)

    # Step 5: Apply Hadamard gates to all qubits again for another layer
    print('--- Applying Hadamard Gates Again (Second Layer) ---')
    sys.stdout.flush()
    All(H) | x0
    All(H) | k
    eng.flush()

    # Step 6: Final measurement and print final ciphertext
    print('--- Measuring Final Ciphertext ---')
    All(Measure) | x0
    All(Measure) | k
    eng.flush()

    print('Final Ciphertext:')
    sys.stdout.flush()
    print_state(eng, x0)

    # Explicitly deallocate qubits
    del x0, k

# Helper function to print the quantum states in hex and binary format
def print_state(eng, qubits):
    eng.flush()
    state = [int(qubit) for qubit in qubits]  # Get the measured state (0 or 1)

    # Convert the state to a binary string
    binary_str = ''.join(str(bit) for bit in state)
    # Print as hex (2 characters per byte)
    hex_str = hex(int(binary_str, 2))[2:].zfill(len(qubits) // 4)
    print(f'Hex: {hex_str.upper()}')
    print(f'Binary: {binary_str}')
    sys.stdout.flush()

# Main function to run the AES-like function with Hadamard gates
def main():
    start_time = time.time()  # Start measuring time

    # Create a quantum engine with a full quantum simulator backend
    sim = Simulator()  # Use full quantum Simulator instead of ClassicalSimulator
    eng = MainEngine(backend=sim, engine_list=[TagRemover()])  # Simplified engine list

    # Run the AES-like quantum circuit
    AES_Hadamard(eng)

    # End measuring time
    end_time = time.time()
    execution_time = end_time - start_time
    print(f'\nExecution Time: {execution_time:.4f} seconds')
    sys.stdout.flush()

# Run the main function
if __name__ == '__main__':
    main()
# Out:
# Text from Plaintext QR Code: Sample plaintext message for AES-64
# Running 'Encryption' with Hadamard-only operations
# Ciphertext from Intermediate QR Code: Intermediate ciphertext representation
# Ciphertext from Final QR Code: Final ciphertext representation
#
# Final 'Ciphertext':
# Block 1:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_main.py:301, in MainEngine.send(self, command_list)
#     300 try:
# --> 301     self.next_engine.receive(command_list)
#     302 except Exception as err:  # pylint: disable=broad-except
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_tagremover.py:65, in TagRemover.receive(self, command_list)
#      64     cmd.tags = [t for t in cmd.tags if not isinstance(t, tag)]
# ---> 65 self.send([cmd])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:186, in BasicEngine.send(self, command_list)
#     185 """Forward the list of commands to the next engine in the pipeline."""
# --> 186 self.next_engine.receive(command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_optimize.py:255, in LocalOptimizer.receive(self, command_list)
#     254 else:
# --> 255     self._cache_cmd(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_optimize.py:231, in LocalOptimizer._cache_cmd(self, cmd)
#     229     self._l[qubit_id] += [cmd]
# --> 231 self._check_and_send()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_optimize.py:213, in LocalOptimizer._check_and_send(self)
#     212         elif len(self._l[i]) > 0 and isinstance(self._l[i][-1].gate, FastForwardingGate):
# --> 213             self._send_qubit_pipeline(i, len(self._l[i]))
#     214 new_dict = {}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_optimize.py:84, in LocalOptimizer._send_qubit_pipeline(self, idx, n_gates)
#      82     # all qubits that need to be flushed have been flushed
#      83     # --> send on the n-qubit gate
# ---> 84     self.send([il[i]])
#      85 # n operations have been sent on --> resize our gate list
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:186, in BasicEngine.send(self, command_list)
#     185 """Forward the list of commands to the next engine in the pipeline."""
# --> 186 self.next_engine.receive(command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:232, in AutoReplacer.receive(self, command_list)
#     231 if not isinstance(cmd.gate, FlushGate):
# --> 232     self._process_command(cmd)
#     233 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:218, in AutoReplacer._process_command(self, cmd)
#     216 # (and not to main engine, which would screw up the ordering).
# --> 218 chosen_decomp.decompose(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\h2rx.py:42, in _decompose_h2rx_N(cmd)
#      41 qubit = cmd.qubits[0]
# ---> 42 Ry(math.pi / 2) | qubit
#      43 Ph(3 * math.pi / 2) | qubit
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_basics.py:202, in BasicGate.__or__(self, qubits)
#     201 cmd = self.generate_command(qubits)
# --> 202 apply_command(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_command.py:68, in apply_command(cmd)
#      67 engine = cmd.engine
# ---> 68 engine.receive([cmd])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:219, in ForwarderEngine.receive(self, command_list)
#     218 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# --> 219 self.send(new_command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:186, in BasicEngine.send(self, command_list)
#     185 """Forward the list of commands to the next engine in the pipeline."""
# --> 186 self.next_engine.receive(command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_cmdmodifier.py:62, in CommandModifier.receive(self, command_list)
#      61 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# ---> 62 self.send(new_command_list)
#
#     [... skipping similar frames: BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:232, in AutoReplacer.receive(self, command_list)
#     231 if not isinstance(cmd.gate, FlushGate):
# --> 232     self._process_command(cmd)
#     233 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:218, in AutoReplacer._process_command(self, cmd)
#     216 # (and not to main engine, which would screw up the ordering).
# --> 218 chosen_decomp.decompose(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\ry2rz.py:32, in _decompose_ry(cmd)
#      31 with Compute(eng):
# ---> 32     Rx(math.pi / 2.0) | qubit
#      33 Rz(angle) | qubit
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_basics.py:202, in BasicGate.__or__(self, qubits)
#     201 cmd = self.generate_command(qubits)
# --> 202 apply_command(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_command.py:68, in apply_command(cmd)
#      67 engine = cmd.engine
# ---> 68 engine.receive([cmd])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:219, in ForwarderEngine.receive(self, command_list)
#     218 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# --> 219 self.send(new_command_list)
#
#     [... skipping similar frames: BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\meta\_compute.py:217, in ComputeEngine.receive(self, command_list)
#     216         tags.append(ComputeTag())
# --> 217     self.send(command_list)
#     218 else:
#
#     [... skipping similar frames: BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_cmdmodifier.py:62, in CommandModifier.receive(self, command_list)
#      61 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# ---> 62 self.send(new_command_list)
#
#     [... skipping similar frames: AutoReplacer._process_command at line 218 (1 times), AutoReplacer.receive at line 232 (1 times), BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\rx2rz.py:30, in _decompose_rx(cmd)
#      29 with Compute(eng):
# ---> 30     H | qubit
#      31 Rz(angle) | qubit
#
#     [... skipping similar frames: BasicGate.__or__ at line 202 (1 times), apply_command at line 68 (1 times), ForwarderEngine.receive at line 219 (1 times), BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\meta\_compute.py:217, in ComputeEngine.receive(self, command_list)
#     216         tags.append(ComputeTag())
# --> 217     self.send(command_list)
#     218 else:
#
#     [... skipping similar frames: BasicEngine.send at line 186 (2 times), AutoReplacer._process_command at line 218 (1 times), CommandModifier.receive at line 62 (1 times), AutoReplacer.receive at line 232 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\h2rx.py:42, in _decompose_h2rx_N(cmd)
#      41 qubit = cmd.qubits[0]
# ---> 42 Ry(math.pi / 2) | qubit
#      43 Ph(3 * math.pi / 2) | qubit
#
#     [... skipping similar frames: BasicEngine.send at line 186 (2 times), BasicGate.__or__ at line 202 (1 times), AutoReplacer._process_command at line 218 (1 times), apply_command at line 68 (1 times), ForwarderEngine.receive at line 219 (1 times), CommandModifier.receive at line 62 (1 times), AutoReplacer.receive at line 232 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\ry2rz.py:32, in _decompose_ry(cmd)
#      31 with Compute(eng):
# ---> 32     Rx(math.pi / 2.0) | qubit
#      33 Rz(angle) | qubit
#
#     [... skipping similar frames: BasicEngine.send at line 186 (3 times), BasicGate.__or__ at line 202 (1 times), AutoReplacer._process_command at line 218 (1 times), apply_command at line 68 (1 times), ForwarderEngine.receive at line 219 (1 times), ComputeEngine.receive at line 217 (1 times), CommandModifier.receive at line 62 (1 times), AutoReplacer.receive at line 232 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\rx2rz.py:30, in _decompose_rx(cmd)
#      29 with Compute(eng):
# ---> 30     H | qubit
#      31 Rz(angle) | qubit
#
#     [... skipping similar frames: BasicEngine.send at line 186 (357 times), BasicGate.__or__ at line 202 (134 times), AutoReplacer._process_command at line 218 (134 times), apply_command at line 68 (134 times), ForwarderEngine.receive at line 219 (134 times), CommandModifier.receive at line 62 (134 times), AutoReplacer.receive at line 232 (134 times), ComputeEngine.receive at line 217 (89 times), _decompose_h2rx_N at line 42 (45 times), _decompose_rx at line 30 (44 times), _decompose_ry at line 32 (44 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\ry2rz.py:32, in _decompose_ry(cmd)
#      31 with Compute(eng):
# ---> 32     Rx(math.pi / 2.0) | qubit
#      33 Rz(angle) | qubit
#
#     [... skipping similar frames: BasicEngine.send at line 186 (3 times), BasicGate.__or__ at line 202 (1 times), AutoReplacer._process_command at line 218 (1 times), apply_command at line 68 (1 times), ForwarderEngine.receive at line 219 (1 times), ComputeEngine.receive at line 217 (1 times), CommandModifier.receive at line 62 (1 times), AutoReplacer.receive at line 232 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\rx2rz.py:30, in _decompose_rx(cmd)
#      29 with Compute(eng):
# ---> 30     H | qubit
#      31 Rz(angle) | qubit
#
#     [... skipping similar frames: BasicGate.__or__ at line 202 (1 times), apply_command at line 68 (1 times), ForwarderEngine.receive at line 219 (1 times), BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\meta\_compute.py:217, in ComputeEngine.receive(self, command_list)
#     216         tags.append(ComputeTag())
# --> 217     self.send(command_list)
#     218 else:
#
#     [... skipping similar frames: BasicEngine.send at line 186 (2 times), AutoReplacer._process_command at line 218 (1 times), CommandModifier.receive at line 62 (1 times), AutoReplacer.receive at line 232 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\h2rx.py:42, in _decompose_h2rx_N(cmd)
#      41 qubit = cmd.qubits[0]
# ---> 42 Ry(math.pi / 2) | qubit
#      43 Ph(3 * math.pi / 2) | qubit
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_basics.py:202, in BasicGate.__or__(self, qubits)
#     201 cmd = self.generate_command(qubits)
# --> 202 apply_command(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_command.py:68, in apply_command(cmd)
#      67 engine = cmd.engine
# ---> 68 engine.receive([cmd])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:219, in ForwarderEngine.receive(self, command_list)
#     218 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# --> 219 self.send(new_command_list)
#
#     [... skipping similar frames: BasicEngine.send at line 186 (1 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_cmdmodifier.py:62, in CommandModifier.receive(self, command_list)
#      61 new_command_list = [self._cmd_mod_fun(cmd) for cmd in command_list]
# ---> 62 self.send(new_command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_basics.py:186, in BasicEngine.send(self, command_list)
#     185 """Forward the list of commands to the next engine in the pipeline."""
# --> 186 self.next_engine.receive(command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:232, in AutoReplacer.receive(self, command_list)
#     231 if not isinstance(cmd.gate, FlushGate):
# --> 232     self._process_command(cmd)
#     233 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_replacer\_replacer.py:218, in AutoReplacer._process_command(self, cmd)
#     216 # (and not to main engine, which would screw up the ordering).
# --> 218 chosen_decomp.decompose(cmd)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\setups\decompositions\ry2rz.py:31, in _decompose_ry(cmd)
#      30 with Control(eng, cmd.control_qubits):
# ---> 31     with Compute(eng):
#      32         Rx(math.pi / 2.0) | qubit
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\meta\_compute.py:313, in Compute.__enter__(self)
#     312 self._compute_eng = ComputeEngine()
# --> 313 insert_engine(self.engine, self._compute_eng)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\meta\_util.py:32, in insert_engine(prev_engine, engine_to_insert)
#      31     if prev_engine.main_engine.n_engines > prev_engine.main_engine.n_engines_max:
# ---> 32         raise RuntimeError('Too many compiler engines added to the MainEngine!')
#      34 engine_to_insert.main_engine = prev_engine.main_engine
#
# RuntimeError: Too many compiler engines added to the MainEngine!
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 96
#      93 start_time = time.time()
#      95 # Run Double AES for encryption
# ---> 96 Double_AES(eng, 0)
#      97 encryption_time = time.time() - start_time
#      99 # Estimate cost
#
# Cell In[1], line 53, in Double_AES(eng, resource_check)
#      51 print("\nFinal 'Ciphertext':")
#      52 print("Block 1:", end=" ")
# ---> 53 print_state(eng, x1, 8)
#      54 print("Block 2:", end=" ")
#      55 print_state(eng, x0, 8)
#
# Cell In[1], line 72, in print_state(eng, b, n)
#      71 def print_state(eng, b, n):
# ---> 72     All(Measure) | b
#      73     print('0x', end='')
#      74     print_hex(eng, b, n)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_metagates.py:282, in Tensor.__or__(self, qubits)
#     279     raise ValueError('Tensor/All must be applied to a list of qubits!')
#     281 for qubit in qubits:
# --> 282     self._gate | qubit
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_gates.py:414, in MeasureGate.__or__(self, qubits)
#     412         num_qubits += 1
#     413         cmd = self.generate_command(([qubit],))
# --> 414         apply_command(cmd)
#     415 if num_qubits > 1:  # pragma: no cover
#     416     raise RuntimeError('Measure is a single qubit gate. Use All(Measure) | qureg instead')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\ops\_command.py:68, in apply_command(cmd)
#      59 """
#      60 Apply a command.
#      61
#    (...)
#      65     cmd (Command): Command to apply
#      66 """
#      67 engine = cmd.engine
# ---> 68 engine.receive([cmd])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_main.py:292, in MainEngine.receive(self, command_list)
#     284 def receive(self, command_list):
#     285     """
#     286     Forward the list of commands to the first engine.
#     287
#    (...)
#     290             then send on)
#     291     """
# --> 292     self.send(command_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\projectq\cengines\_main.py:312, in MainEngine.send(self, command_list)
#     308 compact_exception = exc_type(
#     309     str(exc_value) + '\n raised in:\n' + repr(last_line[-3]) + "\n" + repr(last_line[-2])
#     310 )
#     311 compact_exception.__cause__ = None
# --> 312 raise compact_exception from err
#
# RuntimeError: Too many compiler engines added to the MainEngine!
#  raised in:
# '  File "C:\\Users\\jimmy\\AppData\\Roaming\\Python\\Python311\\site-packages\\projectq\\meta\\_util.py", line 32, in insert_engine'
# "    raise RuntimeError('Too many compiler engines added to the MainEngine!')"
